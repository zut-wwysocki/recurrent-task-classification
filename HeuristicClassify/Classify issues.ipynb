# %% [markdown]
# # Classify issues Pn-g4 -> Pn-g4-c

# %%
import sys
import os
import pandas as pd
import numpy as np

# %%
classes = {
    '???': 0,
    'ADM': 1,
    'BLD': 2,
    'CFG': 3,
    'CUST': 4,
    'DEV': 5,
    'DOC': 6,
    'EDU': 7,
    'MIGR': 8,
    'MIT': 9,
    'PM': 10,
    'RQM': 11,
    'RVW': 12,
    'TST': 13,
    'BUG': 14
}

# %%
Issues = {
    'P1': 'P1-g4',
    'P2': 'P2-g4',
    'P3': 'P3-g4',
    'P4': 'P4-g4',
    'P5': 'P5-g4',
    'P6': 'P6-g4',
}

Tawos = {
    'XD': 'XD',
    'DATACASS': 'DATACASS',
    'NEXUS': 'NEXUS',
    'MESOS': 'MESOS',
    'USERGRID': 'USERGRID',
    'MXNET': 'MXNET',
    'ALOY': 'ALOY',
    'APSTUD': 'APSTUD',
    'CLI': 'CLI',
    'DAEMON': 'DAEMON',
    'TIDOC': 'TIDOC',
    'TIMOB': 'TIMOB',
    'TISTUD': 'TISTUD',
    'BAM': 'BAM',
    'CLOV': 'CLOV',
    'CWD': 'CWD',
    'FE': 'FE',
    'JRASERVER': 'JRASERVER',
    'JSWCLOUD': 'JSWCLOUD',
    'JSWSERVER': 'JSWSERVER',
    'CONFCLOUD': 'CONFCLOUD',
    'CONFSERVER': 'CONFSERVER',
    'BE': 'BE',
    'FAB': 'FAB',
    'INDY': 'INDY',
    'IS': 'IS',
    'STL': 'STL',
    'DM': 'DM',
    'DURACLOUD': 'DURACLOUD',
    'COMPASS': 'COMPASS',
    'CXX': 'CXX',
    'JAVA': 'JAVA',
    'SERVER': 'SERVER',
    'MDL': 'MDL',
    'APIKIT': 'APIKIT',
    'MULE': 'MULE',
    'DNN': 'DNN', 
}

datasets ={
    'Issues': Issues, 
    'Tawos': Tawos
}

datasets_path = "../py-ccflex/temp/processing"

# %%
import keywords_classify as kc

dev_tasks = 'Epic/Story/Improvement/New Feature/Product Improvement/Quick Task/Request/Sub-task/Task'.lower()
rqm_tasks = 'Question/Requirement/Wish/Suggestion'.lower()
tst_tasks = 'Sub-Test/Testing Issue/UAT Test case/Test'.lower()
doc_tasks = 'Documentation'.lower()
adm_tasks = 'Technical task'.lower()
res_df = pd.DataFrame()
res_df['classes'] = [c for c in classes.keys()]
for dataset_name in datasets:
    dataset = datasets[dataset_name]
    for project, repo in list(dataset.items()):
        data_path = f"{datasets_path}/{repo}.csv"
        print(f"- import project {project} from file {data_path}")
        
        data = pd.read_csv(data_path, sep='$')
        df = data.copy().astype({"type_value":"Int64", "state_changes":"Int64", "class_value":"Int64"})

        if dataset_name != 'Tawos': 
            res_df[f"{project}-old"] = ''
            for class_key in classes.keys():
                class_count = df['class_name'].value_counts().get(class_key)
                res_df[f"{project}-old"].iloc[classes[class_key]] = class_count if class_count is not None else 0
        
        for index, row in df.iterrows():
            issue_type = row['type_name'].lower()
            dev_type = issue_type in dev_tasks
            rqm_type = issue_type in rqm_tasks
            tst_type = issue_type in tst_tasks
            bug_type = issue_type in 'bug'
            doc_type = issue_type in doc_tasks
            adm_type = issue_type in adm_tasks
            
            issue_text = f"{row['title']} {row['description']}".lower()
            new_class_name = ''
            # Jeżeli to zadanie jest pytaniem
            if issue_type in 'question': 
                # to jeśli pytający jest deweloperem, to zadanie to wymaganie
                if row['creator'] == 1: 
                    new_class_name = 'RQM'
                # jeśli pytający jest klientem, to zadanie jest obsługą klienta
                else: 
                    new_class_name = 'CUST'
            elif dev_type:
                text_classes = kc.classify_text(issue_text)
                new_class_name = kc.max_class(text_classes) if text_classes else 'DEV'
#                 if 'TRAVEL Maciej'.lower() in issue_text:
#                     print(f">{row['id']}<\n {issue_text}\n{text_classes}\n{new_class_name}")
            elif rqm_type: 
                new_class_name = 'RQM'
            elif bug_type: 
                new_class_name = 'BUG'
            elif tst_type: 
                new_class_name = 'TST'
            elif doc_type: 
                new_class_name = 'DOC'
            elif adm_type: 
                new_class_name = 'ADM'
            else:
                new_class_name = '???'
            df.at[index, 'class_name'] = new_class_name
            df.at[index, 'class_value'] = int(classes[new_class_name]) if new_class_name else int(0)

        res_df[f"{project}-new"] = ''
        for class_key in classes.keys():
            class_count = df['class_name'].value_counts().get(class_key)
            res_df[f"{project}-new"].iloc[classes[class_key]] = class_count if class_count is not None else 0

        out_data_path = f"../py-ccflex/temp/processing/{repo}-c.csv"
        print(f'- export classified issues to {out_data_path}')
        df.to_csv(out_data_path, sep='$', index=False)

out_data_path = '../py-ccflex/temp/processing/classify_result.csv'
print(f'\nExport statistics to {out_data_path}')
res_df.to_csv(out_data_path, sep='\t', index=False)
# Out:
# - import project P1 from file ../py-ccflex/temp/processing/P1-g4.csv
# - export classified issues to ../py-ccflex/temp/processing/P1-g4-c.csv
# - import project P2 from file ../py-ccflex/temp/processing/P2-g4.csv
# - export classified issues to ../py-ccflex/temp/processing/P2-g4-c.csv
# - import project P3 from file ../py-ccflex/temp/processing/P3-g4.csv
# - export classified issues to ../py-ccflex/temp/processing/P3-g4-c.csv
# - import project P4 from file ../py-ccflex/temp/processing/P4-g4.csv
# - export classified issues to ../py-ccflex/temp/processing/P4-g4-c.csv
# - import project P5 from file ../py-ccflex/temp/processing/P5-g4.csv
# - export classified issues to ../py-ccflex/temp/processing/P5-g4-c.csv
# - import project P6 from file ../py-ccflex/temp/processing/P6-g4.csv
# - export classified issues to ../py-ccflex/temp/processing/P6-g4-c.csv
# - import project XD from file ../py-ccflex/temp/processing/XD.csv
# - export classified issues to ../py-ccflex/temp/processing/XD-c.csv
# - import project DATACASS from file ../py-ccflex/temp/processing/DATACASS.csv
# - export classified issues to ../py-ccflex/temp/processing/DATACASS-c.csv
# - import project NEXUS from file ../py-ccflex/temp/processing/NEXUS.csv
# - export classified issues to ../py-ccflex/temp/processing/NEXUS-c.csv
# - import project MESOS from file ../py-ccflex/temp/processing/MESOS.csv
# - export classified issues to ../py-ccflex/temp/processing/MESOS-c.csv
# - import project USERGRID from file ../py-ccflex/temp/processing/USERGRID.csv
# - export classified issues to ../py-ccflex/temp/processing/USERGRID-c.csv
# - import project MXNET from file ../py-ccflex/temp/processing/MXNET.csv
# - export classified issues to ../py-ccflex/temp/processing/MXNET-c.csv
# - import project ALOY from file ../py-ccflex/temp/processing/ALOY.csv
# - export classified issues to ../py-ccflex/temp/processing/ALOY-c.csv
# - import project APSTUD from file ../py-ccflex/temp/processing/APSTUD.csv
# - export classified issues to ../py-ccflex/temp/processing/APSTUD-c.csv
# - import project CLI from file ../py-ccflex/temp/processing/CLI.csv
# - export classified issues to ../py-ccflex/temp/processing/CLI-c.csv
# - import project DAEMON from file ../py-ccflex/temp/processing/DAEMON.csv
# - export classified issues to ../py-ccflex/temp/processing/DAEMON-c.csv
# - import project TIDOC from file ../py-ccflex/temp/processing/TIDOC.csv
# - export classified issues to ../py-ccflex/temp/processing/TIDOC-c.csv
# - import project TIMOB from file ../py-ccflex/temp/processing/TIMOB.csv
# - export classified issues to ../py-ccflex/temp/processing/TIMOB-c.csv
# - import project TISTUD from file ../py-ccflex/temp/processing/TISTUD.csv
# - export classified issues to ../py-ccflex/temp/processing/TISTUD-c.csv
# - import project BAM from file ../py-ccflex/temp/processing/BAM.csv
# - export classified issues to ../py-ccflex/temp/processing/BAM-c.csv
# - import project CLOV from file ../py-ccflex/temp/processing/CLOV.csv
# - export classified issues to ../py-ccflex/temp/processing/CLOV-c.csv
# - import project CWD from file ../py-ccflex/temp/processing/CWD.csv
# - export classified issues to ../py-ccflex/temp/processing/CWD-c.csv
# - import project FE from file ../py-ccflex/temp/processing/FE.csv
# - export classified issues to ../py-ccflex/temp/processing/FE-c.csv
# - import project JRASERVER from file ../py-ccflex/temp/processing/JRASERVER.csv
# - export classified issues to ../py-ccflex/temp/processing/JRASERVER-c.csv
# - import project JSWCLOUD from file ../py-ccflex/temp/processing/JSWCLOUD.csv
# - export classified issues to ../py-ccflex/temp/processing/JSWCLOUD-c.csv
# - import project JSWSERVER from file ../py-ccflex/temp/processing/JSWSERVER.csv
# - export classified issues to ../py-ccflex/temp/processing/JSWSERVER-c.csv
# - import project CONFCLOUD from file ../py-ccflex/temp/processing/CONFCLOUD.csv
# - export classified issues to ../py-ccflex/temp/processing/CONFCLOUD-c.csv
# - import project CONFSERVER from file ../py-ccflex/temp/processing/CONFSERVER.csv
# - export classified issues to ../py-ccflex/temp/processing/CONFSERVER-c.csv
# - import project BE from file ../py-ccflex/temp/processing/BE.csv
# - export classified issues to ../py-ccflex/temp/processing/BE-c.csv
# - import project FAB from file ../py-ccflex/temp/processing/FAB.csv
# - export classified issues to ../py-ccflex/temp/processing/FAB-c.csv
# - import project INDY from file ../py-ccflex/temp/processing/INDY.csv
# - export classified issues to ../py-ccflex/temp/processing/INDY-c.csv
# - import project IS from file ../py-ccflex/temp/processing/IS.csv
# - export classified issues to ../py-ccflex/temp/processing/IS-c.csv
# - import project STL from file ../py-ccflex/temp/processing/STL.csv
# - export classified issues to ../py-ccflex/temp/processing/STL-c.csv
# - import project DM from file ../py-ccflex/temp/processing/DM.csv
# - export classified issues to ../py-ccflex/temp/processing/DM-c.csv
# - import project DURACLOUD from file ../py-ccflex/temp/processing/DURACLOUD.csv
# - export classified issues to ../py-ccflex/temp/processing/DURACLOUD-c.csv
# - import project COMPASS from file ../py-ccflex/temp/processing/COMPASS.csv
# - export classified issues to ../py-ccflex/temp/processing/COMPASS-c.csv
# - import project CXX from file ../py-ccflex/temp/processing/CXX.csv
# - export classified issues to ../py-ccflex/temp/processing/CXX-c.csv
# - import project JAVA from file ../py-ccflex/temp/processing/JAVA.csv
# - export classified issues to ../py-ccflex/temp/processing/JAVA-c.csv
# - import project SERVER from file ../py-ccflex/temp/processing/SERVER.csv
# - export classified issues to ../py-ccflex/temp/processing/SERVER-c.csv
# - import project MDL from file ../py-ccflex/temp/processing/MDL.csv
# - export classified issues to ../py-ccflex/temp/processing/MDL-c.csv
# - import project APIKIT from file ../py-ccflex/temp/processing/APIKIT.csv
# - export classified issues to ../py-ccflex/temp/processing/APIKIT-c.csv
# - import project MULE from file ../py-ccflex/temp/processing/MULE.csv
# - export classified issues to ../py-ccflex/temp/processing/MULE-c.csv
# - import project DNN from file ../py-ccflex/temp/processing/DNN.csv
# - export classified issues to ../py-ccflex/temp/processing/DNN-c.csv
#
# Export statistics to ../py-ccflex/temp/processing/classify_result.csv

# %%
res_df

# %%
import keywords_classify as kc
text="Brainstorm session to agree ongoing way of working for support (2020-09-16)	This meeting goal is to gree how the team organizes in situations when customer reports incident that needs to be resolved quickly. This is NOT ONLY production related incidents"
text_classes = kc.classify_text(text, debug=True)
print(text_classes)
new_class_name = kc.max_class(text_classes) if text_classes else 'DEV'
print(new_class_name)
# Out:
# {'first': 'brainstorm', 'second': 'session', 'third': '', 'type': 'MIT'} == 2
# {'MIT': 2}
# MIT
